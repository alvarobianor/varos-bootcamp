# %%
# !pip install yfinance==0.1.74
# !pip install mplcyberpunk
# !pip install python-dotenv
# Out:
# Collecting yfinance==0.1.74
#   Using cached yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.15 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from yfinance==0.1.74) (1.20.3)
# Requirement already satisfied: pandas>=0.24.0 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from yfinance==0.1.74) (1.3.4)
# Requirement already satisfied: lxml>=4.5.1 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from yfinance==0.1.74) (4.6.3)
# Requirement already satisfied: requests>=2.26 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from yfinance==0.1.74) (2.26.0)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance==0.1.74) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance==0.1.74) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance==0.1.74) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance==0.1.74) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance==0.1.74) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance==0.1.74) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance==0.1.74) (3.2)
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.11 yfinance-0.1.74
# Collecting mplcyberpunk
#   Using cached mplcyberpunk-0.6.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: matplotlib in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from mplcyberpunk) (3.4.3)
# Requirement already satisfied: numpy>=1.16 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from matplotlib->mplcyberpunk) (2.8.2)
# Requirement already satisfied: six in /home/alvarobianor/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->mplcyberpunk) (1.16.0)
# Installing collected packages: mplcyberpunk
# Successfully installed mplcyberpunk-0.6.0
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
import pandas as pd
import datetime
import yfinance as yf
from matplotlib import pyplot as plt
import mplcyberpunk
import smtplib
from email.message import EmailMessage

# %%
ativos = ["^BVSP", "BRL=X", "^IXIC", "AAPL"]

hoje = datetime.datetime.now()
um_ano_atras = hoje - datetime.timedelta(365*10)

dados_mercado = yf.download(ativos, um_ano_atras, hoje)

dados_fechamento = dados_mercado['Adj Close']

dados_fechamento.columns = ['Dolar', 'Ibovespa', 'Nasdaq', 'Apple']

dados_fechamento = dados_fechamento.dropna()

display(dados_fechamento)
# Out:
# [*********************100%***********************]  4 of 4 completed
#                  Dolar  Ibovespa   Nasdasq         Apple
# Date
# 2013-04-08   13.146768    1.9832   55092.0   3222.250000
# 2013-04-09   13.170519    1.9897   55912.0   3237.860107
# 2013-04-10   13.439187    1.9806   56187.0   3297.250000
# 2013-04-11   13.397236    1.9732   55401.0   3300.159912
# 2013-04-12   13.257507    1.9748   54963.0   3294.949951
# ...                ...       ...       ...           ...
# 2023-03-27  158.279999    5.2451   99670.0  11768.839844
# 2023-03-28  157.649994    5.1971  101185.0  11716.080078
# 2023-03-29  160.770004    5.1644  101793.0  11926.240234
# 2023-03-30  162.360001    5.1342  103713.0  12013.469727
# 2023-03-31  164.899994    5.0927  101882.0  12221.910156
#
# [2410 rows x 4 columns]
